# %% [markdown]
# # 🧮 Aula 1 - Módulo 4
# ### Exercícios completos

# %% [markdown]
# ## Questão 1

# %%
# Leia x e verifique se é maior que 5
x = int(input("Digite um número: "))

if x > 5:
    print("Maior que 5")

print("Fim")

# %% [markdown]
# ## Questão 2

# %%
# Leia n e mostre os valores de 1 até n
n = int(input("Digite um número: "))
cont = 0

while cont < n:
    cont = cont + 1
    print(cont)

print("Fim")

# %% [markdown]
# ## Questão 3

# %%
# Leia 3 notas e calcule a média
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))

m = (n1 + n2 + n3) / 3

if m >= 60:
    print("Aprovado")
elif m >= 40:
    print("Recuperação")
else:
    print("Reprovado")

print("Fim")

# %% [markdown]
# ## Questão 4

# %%
# Leia n valores e mostre o maior deles
n = int(input("Digite a quantidade de números: "))
maior = 0

while n > 0:
    x = int(input("Digite um número: "))
    if x > maior:
        maior = x
    n = n - 1

print("O maior número é:", maior)

# %% [markdown]
# ## Questão 5

# %%
# Calcular a média das idades
N = int(input("Digite a quantidade de respondentes: "))

soma_idades = 0
for i in range(N):
    idade = int(input(f"Digite a idade do respondente {i+1}: "))
    soma_idades += idade

media = soma_idades / N
print("A média das idades é:", media)

# %% [markdown]
# ## Questão 6

# %%
# Experimentos com cobaias
N = int(input("Digite a quantidade de experimentos: "))

total = 0
coelhos = 0
ratos = 0
sapos = 0

for i in range(N):
    entrada = input("Digite a quantidade e o tipo de cobaia (ex: 10 C): ").split()
    quantia = int(entrada[0])
    tipo = entrada[1].upper()

    total += quantia

    if tipo == 'C':
        coelhos += quantia
    elif tipo == 'R':
        ratos += quantia
    elif tipo == 'S':
        sapos += quantia

print(f"Total: {total} cobaias")
print(f"Total de coelhos: {coelhos}")
print(f"Total de ratos: {ratos}")
print(f"Total de sapos: {sapos}")

perc_coelhos = (coelhos / total) * 100
perc_ratos = (ratos / total) * 100
perc_sapos = (sapos / total) * 100

print(f"Percentual de coelhos: {perc_coelhos:.2f} %")
print(f"Percentual de ratos: {perc_ratos:.2f} %")
print(f"Percentual de sapos: {perc_sapos:.2f} %")
